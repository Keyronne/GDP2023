# %%
import os
os.listdir()
# Out:
# ['.config', 'david_key.json', 'drive', '.ipynb_checkpoints', 'sample_data']

# %%
! pip install -q kaggle
#! mkdir ~/.kaggle
#get you kaggle token from the account section and place it in the contents folder.
#Name the kaggle token from you account as kaggle.json
#Then this should work.
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
# ref                                                              title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ahsan81/hotel-reservations-classification-dataset                Hotel Reservations Dataset                          480KB  2023-01-04 12:50:31           6704        232  1.0
# themrityunjaypathak/most-subscribed-1000-youtube-channels        Most Subscribed 1000 Youtube Channels                28KB  2023-01-21 14:42:05            987         37  1.0
# senapatirajesh/netflix-tv-shows-and-movies                       Latest Netflix TV shows and movies                    1MB  2023-01-14 17:03:12           2444         67  0.9411765
# ...

# %%
# !kaggle datasets download -d jonathannield/cctv-human-pose-estimation-dataset
# Out:
# ...
#  97% 433M/445M [00:07<00:00, 94.5MB/s]
# 100% 445M/445M [00:07<00:00, 59.4MB/s]
